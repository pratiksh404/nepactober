# %%
import matplotlib.image as img
import matplotlib.pyplot as plt
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive')
image=img.imread("/content/drive/My Drive/Lenna.png")
image=image[:,:,0]
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
plt.imshow(image)

# %%
plt.title("HIstogramm for given Image'  ")
plt.xlabel("Value")
plt.ylabel("pixels Frequency")
#hist function is used to plot the histogram of an image.
plt.hist(image)
# Out:
# (array([[ 23.,  61.,  47., ...,   3.,  79.,  14.],
#         [ 23.,  61.,  47., ...,   3.,  79.,  14.],
#         [ 24.,  46.,  55., ...,   3.,  78.,  13.],
#         ...,
#         [  5.,  33.,  71., ..., 158.,  61.,  67.],
#         [  4.,  36.,  67., ..., 149.,  65.,  74.],
#         [  4.,  31.,  74., ..., 156.,  59.,  74.]]),
#  array([0.21176471, 0.29058823, 0.36941177, 0.4482353 , 0.52705884,
#         0.60588235, 0.68470585, 0.7635294 , 0.8423529 , 0.9211765 ,
#         1.        ], dtype=float32),
#  <a list of 512 Lists of Patches objects>)

# %%
plt.hist(np.histogram(image.flatten(),256,[0,256]))
# Out:
# /usr/local/lib/python3.6/dist-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)
# (array([[255.,   0.,   0.,   0.,   0.,   0.,   0.,   0.,   0.,   1.],
#         [257.,   0.,   0.,   0.,   0.,   0.,   0.,   0.,   0.,   0.]]),
#  array([     0. ,  26203.2,  52406.4,  78609.6, 104812.8, 131016. ,
#         157219.2, 183422.4, 209625.6, 235828.8, 262032. ]),
#  <a list of 2 Lists of Patches objects>)
